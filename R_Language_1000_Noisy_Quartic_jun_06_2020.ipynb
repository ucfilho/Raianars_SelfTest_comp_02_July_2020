# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# character(0)

# %%
library('DEoptimR')


Noisy_Quartic= function(x)
  {
  Num=length(x)  
  sumx4=0
  for(i in 1:Num)
    { sumx4=sumx4+i*x[i]**4}

  sumx4=sumx4+runif(1)
  return(sumx4)
  }
# f(x)=0 x=(0,0) [−1.28, 1.28]


dim=30
RUNS=50
Y=0;X=0

for(i in 1:RUNS)
  {
  JDE_R=JDEoptim(rep(-1.28, dim), rep(1.28, dim), Noisy_Quartic,
         tol = 1e-20,NP=100, trace = FALSE,  maxiter =1000)
  Y[i]=JDE_R$value

  }


print(Y)
MEAN=mean(Y)
STD=sd(Y)
MAX=max(Y)
MIN=min(Y)
cat('NoisyQuartic JDE DIM=',dim,'RUNS=',RUNS,'\n')
cat('MEAN=',MEAN,'\n')
cat('MAX',MAX,'\n')
cat('MIN=',MIN,'\n')
cat('STD',STD,'\n')
# Out:
# Error in runif(): argument "n" is missing, with no default
# Traceback:
#
# 1. JDEoptim(rep(-1.28, dim), rep(1.28, dim), Noisy_Quartic, tol = 1e-20,
#  .     NP = 100, trace = FALSE, maxiter = 1000)
# 2. apply(pop, 2, fn1)
# 3. FUN(newX[, i], ...)
# 4. fn(par, ...)
# 5. runif()   # at line 11 of file <text>
